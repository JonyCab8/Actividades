# %%
#Actividad 5
#ALUMNO: Jonathan Ramon Cabrera
#MATRICULA: 2020547
#HORA CLASE: N1

#Cargar librerias
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from keras.layers import Flatten, Dense
from keras.models import Sequential

# Cargar datos MNIST
(train_data, train_labels), (test_data, test_labels) = datasets.mnist.load_data()

# Modelo
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_data, train_labels, epochs=10)

# Prueba de modelo
test_loss, test_accuracy = model.evaluate(test_data, test_labels)
print("Exactitud del conjunto de datos:", test_accuracy)

# 5 Predicciones individuales
numero_red = model.predict(test_data)[7].reshape(10, 1)
print("Según la red el numero es:", numero_red, "El numero real es:", test_labels[7])

numero_red = model.predict(test_data)[4].reshape(10, 1)
print("Según la red el numero es:", numero_red, "El numero real es:", test_labels[4])

numero_red = model.predict(test_data)[0].reshape(10, 1)
print("Según la red el numero es:", numero_red, "El numero real es:", test_labels[0])

numero_red = model.predict(test_data)[1].reshape(10, 1)
print("Según la red el numero es:", numero_red, "El numero real es:", test_labels[1])

numero_red = model.predict(test_data)[8].reshape(10, 1)
print("Según la red el numero es:", numero_red, "El numero real es:", test_labels[8])
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 2.4494 - accuracy: 0.8651
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3793 - accuracy: 0.9162
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2880 - accuracy: 0.9316
# Epoch 4/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.2489 - accuracy: 0.9374
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2218 - accuracy: 0.9448
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2123 - accuracy: 0.9474
# Epoch 7/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1950 - accuracy: 0.9517
# Epoch 8/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1891 - accuracy: 0.9536
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1891 - accuracy: 0.9528
# Epoch 10/10
# ...
